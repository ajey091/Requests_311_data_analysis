df['Date'] = pd.to_datetime(df['Created Date']).dt.date
df

# %%
df_lat_long = df.copy()

df_lat_long['Latitude'] = np.round(df_lat_long['Latitude'],2)
df_lat_long['Longitude'] = np.round(df_lat_long['Longitude'],2)

df_lat_long_agg = df_lat_long.groupby(['Latitude','Longitude']).size().reset_index(name='counts')
df_lat_long_agg['Density'] = df_lat_long_agg['counts']/df_lat_long_agg['counts'].sum()

color_scale = [(0, 'orange'), (1,'red')]

fig = px.density_mapbox(df_lat_long_agg, 
                        lat="Latitude", 
                        lon="Longitude", 
                        z="Density",
                        color_continuous_scale='viridis',
                        zoom=9, 
                        radius=26,
                        height=800,
                        width=900)

fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
pd.to_datetime(df['Created Date']).dt.date

# %%
plt.rcParams.update({'font.size': 20})
                           
complaint_frequency = np.round(100*df[['Complaint Type']].value_counts().head(30)/len(df),2).reset_index(name='Fraction_of_all_calls')

fig, ax = plt.subplots(figsize=(12,10))

sns.barplot(data=complaint_frequency, y="Complaint Type", x="Fraction_of_all_calls", 
            color='b', ax=ax, orient="h")
# plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
agency_frequency = df["Agency Name"].value_counts()[0:30].reset_index(name='Frequency')
                           
agency_frequency = np.round(100*df[['Agency Name']].value_counts().head(30)/len(df),2).reset_index(name='Fraction_of_all_calls')


fig, ax = plt.subplots(figsize=(12,10))

sns.barplot(data=agency_frequency, y="Agency Name", x="Fraction_of_all_calls", 
            color='b', ax=ax, orient="h")
# plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
complaint_frequencies = df.groupby(['Date','Complaint Type']).size().reset_index(name='Frequency')
complaint_frequencies

# %%
df.groupby(['Date']).size().reset_index(name='Frequency')

# %%
fig, ax = plt.subplots(figsize=(14,10))

sns.histplot(data=df.groupby(['Date']).size().reset_index(name='Frequency'), x="Date", weights="Frequency", 
            palette='Set1', ax=ax, element='step', bins=100)
plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
noise = complaint_frequencies.loc[complaint_frequencies['Complaint Type'] == 'Damaged Tree']
                           
fig, ax = plt.subplots(figsize=(14,10))

sns.histplot(data=noise, x="Date", weights="Frequency", hue='Complaint Type',
            color='b', ax=ax, element='step', bins=100, )
plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
dot = complaint_frequencies.loc[complaint_frequencies['Agency Type'] == 'Deparmen']
                           
fig, ax = plt.subplots(figsize=(14,10))

sns.histplot(data=noise, x="Date", weights="Frequency", hue='Complaint Type',
            color='b', ax=ax, element='step', bins=100, )
plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
weather_data = pd.read_csv('weather_NY_2010_2018Nov.csv')
weather_data

weather_data['dt'] = pd.to_datetime(weather_data.Year.astype(str) + '/' + weather_data.Month.astype(str) + '/' + weather_data.Day.astype(str))

weather_data
# Out:
#           USAF   WBAN               StationName State  Latitude  Longitude  \
# 0       726228  94740  ADIRONDACK REGIONAL ARPT    NY    44.385    -74.207
# 1       726228  94740  ADIRONDACK REGIONAL ARPT    NY    44.385    -74.207
# 2       726228  94740  ADIRONDACK REGIONAL ARPT    NY    44.385    -74.207
# 3       726228  94740  ADIRONDACK REGIONAL ARPT    NY    44.385    -74.207
# 4       726228  94740  ADIRONDACK REGIONAL ARPT    NY    44.385    -74.207
# ...        ...    ...                       ...   ...       ...        ...
# 160770  743700  14715  WHEELER-SACK AAF AIRPORT    NY    44.050    -75.733
# 160771  743700  14715  WHEELER-SACK AAF AIRPORT    NY    44.050    -75.733
# 160772  743700  14715  WHEELER-SACK AAF AIRPORT    NY    44.050    -75.733
# 160773  743700  14715  WHEELER-SACK AAF AIRPORT    NY    44.050    -75.733
# 160774  743700  14715  WHEELER-SACK AAF AIRPORT    NY    44.050    -75.733
#
#         MeanTemp  MinTemp  MaxTemp  DewPoint  ...  WindSpeed  \
# 0           27.6     24.8     30.9      25.0  ...        1.3
# 1           -3.2    -20.9     17.1      -9.6  ...        3.3
# 2           20.9     17.1     24.1      15.1  ...        6.8
# 3           13.8      5.0     19.9       8.5  ...        4.4
# 4            6.3     -8.0     19.0       1.9  ...        3.3
# ...          ...      ...      ...       ...  ...        ...
# 160770      78.4     68.5     90.9      71.6  ...        7.2
# 160771      75.3     66.2     82.0      71.4  ...        6.2
# 160772      63.0     51.4     73.2      54.0  ...        3.5
# 160773      56.4     49.5     73.2      45.7  ...        6.4
# 160774      51.3     40.6     62.6      43.4  ...        5.5
#
#         MaxSustainedWind  Gust  Rain  SnowDepth  SnowIce  Year  Month  Day  \
# 0                    6.0   NaN     0        NaN        1  2010      1    1
# 1                    9.9   NaN     0        NaN        1  2010      1   10
# 2                   12.0  19.0     0        NaN        1  2010      1   11
# 3                    8.0  15.9     0        NaN        1  2010      1   12
# 4                    5.1   NaN     0        NaN        1  2010      1   13
# ...                  ...   ...   ...        ...      ...   ...    ...  ...
# 160770              13.0  19.0     0        NaN        0  2018      9    5
# 160771               9.9  17.1     1        NaN        0  2018      9    6
# 160772               8.0   NaN     0        NaN        0  2018      9    7
# 160773              14.0  20.0     0        NaN        0  2018      9    8
# 160774               8.9   NaN     0        NaN        0  2018      9    9
#
#                dt
# 0      2010-01-01
# 1      2010-01-10
# 2      2010-01-11
# 3      2010-01-12
# 4      2010-01-13
# ...           ...
# 160770 2018-09-05
# 160771 2018-09-06
# 160772 2018-09-07
# 160773 2018-09-08
# 160774 2018-09-09
#
# [160775 rows x 21 columns]

# %%
noise = complaint_frequencies.loc[complaint_frequencies['Complaint Type'] == 'Damaged Tree']
                           
fig, ax = plt.subplots(figsize=(14,10))

sns.histplot(data=noise, x="Date", weights="Frequency", hue='Complaint Type',
            color='b', ax=ax, element='step', bins=100, )

ax2 = ax.twinx()

sns.histplot(data=weather_data.loc[weather_data['dt'] > pd.to_datetime('2016-01-01')], 
             x="dt", weights="Gust", fill=False,
            color='r', ax=ax2, element='step', bins=500, alpha =0.5)
# sns.barplot(data=weather_data.loc[weather_data['dt'] > pd.to_datetime('2016-01-01')], x="dt", y='Percipitation', color='g', ax=ax2 )

plt.setp(ax.get_xticklabels(), rotation=90, ha='center')
ax.grid()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.merge(weather_data, left_on='Date', right_on='dt')
# Out:
#           Unique Key            Created Date             Closed Date Agency  \
# 0           38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# 1           38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# 2           38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# 3           38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# 4           38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# ...              ...                     ...                     ...    ...
# 46478479    38237842  01/17/2018 09:39:00 AM  01/18/2018 09:39:00 PM   DSNY
# 46478480    38237842  01/17/2018 09:39:00 AM  01/18/2018 09:39:00 PM   DSNY
# 46478481    38237842  01/17/2018 09:39:00 AM  01/18/2018 09:39:00 PM   DSNY
# 46478482    38237842  01/17/2018 09:39:00 AM  01/18/2018 09:39:00 PM   DSNY
# 46478483    38237842  01/17/2018 09:39:00 AM  01/18/2018 09:39:00 PM   DSNY
#
#                        Agency Name                       Complaint Type  \
# 0         Department of Sanitation  Request Large Bulky Item Collection
# 1         Department of Sanitation  Request Large Bulky Item Collection
# 2         Department of Sanitation  Request Large Bulky Item Collection
# 3         Department of Sanitation  Request Large Bulky Item Collection
# 4         Department of Sanitation  Request Large Bulky Item Collection
# ...                            ...                                  ...
# 46478479  Department of Sanitation  Request Large Bulky Item Collection
# 46478480  Department of Sanitation  Request Large Bulky Item Collection
# 46478481  Department of Sanitation  Request Large Bulky Item Collection
# 46478482  Department of Sanitation  Request Large Bulky Item Collection
# 46478483  Department of Sanitation  Request Large Bulky Item Collection
#
#                                    Descriptor Location Type Incident Zip  \
# 0         Request Large Bulky Item Collection      Sidewalk        11215
# 1         Request Large Bulky Item Collection      Sidewalk        11215
# 2         Request Large Bulky Item Collection      Sidewalk        11215
# 3         Request Large Bulky Item Collection      Sidewalk        11215
# 4         Request Large Bulky Item Collection      Sidewalk        11215
# ...                                       ...           ...          ...
# 46478479  Request Large Bulky Item Collection      Sidewalk      11378.0
# 46478480  Request Large Bulky Item Collection      Sidewalk      11378.0
# 46478481  Request Large Bulky Item Collection      Sidewalk      11378.0
# 46478482  Request Large Bulky Item Collection      Sidewalk      11378.0
# 46478483  Request Large Bulky Item Collection      Sidewalk      11378.0
#
#          Incident Address  ... WindSpeed MaxSustainedWind  Gust Rain  \
# 0            160 7 AVENUE  ...       2.3              8.0   NaN    0
# 1            160 7 AVENUE  ...       5.4             13.0  17.1    0
# 2            160 7 AVENUE  ...       0.0              NaN   NaN    0
# 3            160 7 AVENUE  ...       3.8              9.9   NaN    1
# 4            160 7 AVENUE  ...      13.6             20.0  28.0    0
# ...                   ...  ...       ...              ...   ...  ...
# 46478479   60-14 55 DRIVE  ...       6.1             15.0   NaN    0
# 46478480   60-14 55 DRIVE  ...       0.0              NaN   NaN    0
# 46478481   60-14 55 DRIVE  ...       4.4             15.0  19.0    0
# 46478482   60-14 55 DRIVE  ...       6.4             15.9   NaN    1
# 46478483   60-14 55 DRIVE  ...       5.9             14.0  18.1    0
#
#          SnowDepth SnowIce  Year Month Day         dt
# 0              NaN       1  2018     1  17 2018-01-17
# 1              5.9       1  2018     1  17 2018-01-17
# 2              NaN       0  2018     1  17 2018-01-17
# 3              NaN       1  2018     1  17 2018-01-17
# 4              9.1       1  2018     1  17 2018-01-17
# ...            ...     ...   ...   ...  ..        ...
# 46478479       9.8       1  2018     1  17 2018-01-17
# 46478480       NaN       0  2018     1  17 2018-01-17
# 46478481       NaN       1  2018     1  17 2018-01-17
# 46478482       NaN       1  2018     1  17 2018-01-17
# 46478483       9.1       1  2018     1  17 2018-01-17
#
# [46478484 rows x 64 columns]

# %%
import polars as pl
df_pl = pl.read_csv(filename, n_rows=1000000)  
df_pl
# Out:
# shape: (1000000, 42)
# ┌──────────┬────────────┬───────────┬────────┬─────┬───────────┬───────────┬──────────┬────────────┐
# │ Unique   ┆ Created    ┆ Closed    ┆ Agency ┆ ... ┆ Latitude  ┆ Longitude ┆ Location ┆ Created    │
# │ Key      ┆ Date       ┆ Date      ┆ ---    ┆     ┆ ---       ┆ ---       ┆ ---      ┆ Year       │
# │ ---      ┆ ---        ┆ ---       ┆ str    ┆     ┆ str       ┆ str       ┆ str      ┆ ---        │
# │ i64      ┆ str        ┆ str       ┆        ┆     ┆           ┆           ┆          ┆ i64        │
# ╞══════════╪════════════╪═══════════╪════════╪═════╪═══════════╪═══════════╪══════════╪════════════╡
# │ 38237851 ┆ 01/17/2018 ┆ 01/24/201 ┆ DSNY   ┆ ... ┆ 40.730012 ┆ -73.95626 ┆ (40.7300 ┆ 2018       │
# │          ┆ 02:39:00   ┆ 8         ┆        ┆     ┆ 99919553  ┆ 650502489 ┆ 12999195 ┆            │
# │          ┆ PM         ┆ 12:00:00  ┆        ┆     ┆           ┆           ┆ 53, -73. ┆            │
# │          ┆            ┆ AM        ┆        ┆     ┆           ┆           ┆ 95626650 ┆            │
# │          ┆            ┆           ┆        ┆     ┆           ┆           ┆ ...      ┆            │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 38237852 ┆ 01/17/2018 ┆ 01/21/201 ┆ DSNY   ┆ ... ┆ 40.558494 ┆ -74.14196 ┆ (40.5584 ┆ 2018       │
# │          ┆ 01:40:00   ┆ 8         ┆        ┆     ┆ 382393974 ┆ 245468202 ┆ 94382393 ┆            │
# │          ┆ PM         ┆ 12:00:00  ┆        ┆     ┆           ┆           ┆ 974, -74 ┆            │
# │          ┆            ┆ AM        ┆        ┆     ┆           ┆           ┆ .1419624 ┆            │
# │          ┆            ┆           ┆        ┆     ┆           ┆           ┆ ...      ┆            │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │
�╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 39510897 ┆ 06/19/2018 ┆ 09/18/201 ┆ TLC    ┆ ... ┆ 40.753257 ┆ -73.88947 ┆ (40.7532 ┆ 2018       │
# │          ┆ 07:44:36   ┆ 8         ┆        ┆     ┆ 4946208   ┆ 851327453 ┆ 57494620 ┆            │
# │          ┆ AM         ┆ 09:43:26  ┆        ┆     ┆           ┆           ┆ 8, -73.8 ┆            │
# │          ┆            ┆ AM        ┆        ┆     ┆           ┆           ┆ 89478513 ┆            │
# │          ┆            ┆           ┆        ┆     ┆           ┆           ┆ ...      ┆            │
# └──────────┴────────────┴───────────┴────────┴─────┴───────────┴───────────┴──────────┴────────────┘

# %%
df_pd = pd.read_csv(filename, nrows=1000000)  
df_pd
# Out:
# /var/folders/1q/kqvp77k931q_0cj81wm8j_zm0000gp/T/ipykernel_6411/841813270.py:1: DtypeWarning:
#
# Columns (8,17,31,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#         Unique Key            Created Date             Closed Date Agency  \
# 0         38237851  01/17/2018 02:39:00 PM  01/24/2018 12:00:00 AM   DSNY
# 1         38237852  01/17/2018 01:40:00 PM  01/21/2018 12:00:00 AM   DSNY
# 2         38237855  01/17/2018 10:42:00 PM  01/20/2018 10:02:00 PM   DSNY
# 3         38237856  01/17/2018 07:26:00 PM  01/19/2018 12:00:00 AM   DSNY
# 4         38237857  01/17/2018 07:13:00 PM  01/20/2018 07:41:00 PM   DSNY
# ...            ...                     ...                     ...    ...
# 999995    39510893  06/19/2018 08:03:00 PM  06/19/2018 09:00:00 PM    DOT
# 999996    39510894  06/19/2018 12:00:00 AM  06/19/2018 12:00:01 AM  DOHMH
# 999997    39510895  06/19/2018 11:45:33 AM  07/19/2018 12:52:15 PM    DOE
# 999998    39510896  06/19/2018 12:36:26 PM  08/19/2018 06:17:21 AM  DOHMH
# 999999    39510897  06/19/2018 07:44:36 AM  09/18/2018 09:43:26 AM    TLC
#
#                                     Agency Name  \
# 0                      Department of Sanitation
# 1                      Department of Sanitation
# 2                      Department of Sanitation
# 3                      Department of Sanitation
# 4                      Department of Sanitation
# ...                                         ...
# 999995             Department of Transportation
# 999996  Department of Health and Mental Hygiene
# 999997                          School - PS 291
# 999998  Department of Health and Mental Hygiene
# 999999            Taxi and Limousine Commission
#
#                              Complaint Type  \
# 0       Request Large Bulky Item Collection
# 1       Request Large Bulky Item Collection
# 2       Request Large Bulky Item Collection
# 3       Request Large Bulky Item Collection
# 4       Request Large Bulky Item Collection
# ...                                     ...
# 999995             Traffic Signal Condition
# 999996                       Food Poisoning
# 999997                   School Maintenance
# 999998                   Food Establishment
# 999999           For Hire Vehicle Complaint
#
#                                  Descriptor               Location Type  \
# 0       Request Large Bulky Item Collection                    Sidewalk
# 1       Request Large Bulky Item Collection                    Sidewalk
# 2       Request Large Bulky Item Collection                    Sidewalk
# 3       Request Large Bulky Item Collection                    Sidewalk
# 4       Request Large Bulky Item Collection                    Sidewalk
# ...                                     ...                         ...
# 999995                           Controller                         NaN
# 999996                               1 or 2  Restaurant/Bar/Deli/Bakery
# 999997             Air Conditioning Problem                      School
# 999998                         Food Spoiled  Restaurant/Bar/Deli/Bakery
# 999999                     Driver Complaint                      Street
#
#        Incident Zip      Incident Address  ... Taxi Company Borough  \
# 0             11222  95 GREENPOINT AVENUE  ...                  NaN
# 1             10308      40 ASHWOOD COURT  ...                  NaN
# 2             11361        204-36 47 ROAD  ...                  NaN
# 3             10467    3851 BARNES AVENUE  ...                  NaN
# 4             11215          160 7 AVENUE  ...                  NaN
# ...             ...                   ...  ...                  ...
# 999995      11210.0                   NaN  ...                  NaN
# 999996      10451.0  196 EAST  161 STREET  ...                  NaN
# 999997      10453.0   2195 ANDREWS AVENUE  ...                  NaN
# 999998      11101.0       30-30 47 AVENUE  ...                  NaN
# 999999      11372.0       77-10 34 AVENUE  ...                  NaN
#
#        Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                        NaN                 NaN                      NaN
# 1                        NaN                 NaN                      NaN
# 2                        NaN                 NaN                      NaN
# 3                        NaN                 NaN                      NaN
# 4                        NaN                 NaN                      NaN
# ...                      ...                 ...                      ...
# 999995                   NaN                 NaN                      NaN
# 999996                   NaN                 NaN                      NaN
# 999997                   NaN                 NaN                      NaN
# 999998                   NaN                 NaN                      NaN
# 999999                   NaN                 NaN                      NaN
#
#        Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0            NaN                    NaN  40.730013 -73.956267
# 1            NaN                    NaN  40.558494 -74.141962
# 2            NaN                    NaN  40.754075 -73.775594
# 3            NaN                    NaN  40.884181 -73.859111
# 4            NaN                    NaN  40.672113 -73.977242
# ...          ...                    ...        ...        ...
# 999995       NaN                    NaN  40.619605 -73.945518
# 999996       NaN                    NaN  40.826431 -73.921288
# 999997       NaN                    NaN  40.858810 -73.909746
# 999998       NaN                    NaN  40.743168 -73.936568
# 999999       NaN                    NaN  40.753257 -73.889479
#
#                                         Location Created Year
# 0        (40.73001299919553, -73.95626650502489)         2018
# 1       (40.558494382393974, -74.14196245468202)         2018
# 2        (40.75407455058778, -73.77559379608053)         2018
# 3        (40.88418051177941, -73.85911054646147)         2018
# 4        (40.67211272839247, -73.97724198791173)         2018
# ...                                          ...          ...
# 999995   (40.61960532878832, -73.94551810926144)         2018
# 999996   (40.82643073691624, -73.92128776514645)         2018
# 999997  (40.858809848306564, -73.90974630644877)         2018
# 999998   (40.74316767130191, -73.93656831501343)         2018
# 999999    (40.7532574946208, -73.88947851327453)         2018
#
# [1000000 rows x 42 columns]
